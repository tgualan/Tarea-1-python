# %%
#Tarea 1 Python

# %%
# !pip list # lista de paquetes
# Out:
# Package                           Version
# --------------------------------- --------------------
# absl-py                           1.2.0
# accelerate                        0.22.0
# aenum                             3.1.11
# affine                            2.3.1
# agate                             1.7.0
# aiohttp                           3.8.1
# aiosignal                         1.2.0
# ansi2html                         1.8.0
# ansiwrap                          0.8.4
# anyio                             3.6.1
# appdirs                           1.4.4
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.2
# asn1crypto                        1.5.1
# asttokens                         2.0.8
# astunparse                        1.6.3
# async-timeout                     4.0.2
# attrs                             21.4.0
# autopep8                          2.0.0
# awscli                            1.29.40
# ...

# %%
import numpy as np #importando un paquete

# %%
mi_nombre = ["Tamia"]
mi_edad = [25]

# %%
informacion_Tamia = mi_nombre + mi_edad
print(informacion_Tamia)
# Out:
# ['Tamia', 25]
